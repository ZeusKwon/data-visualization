# %%
# %matplotlib inline
import pandas as pd

# 스타벅스 음료의 칼로리를 박스 플롯으로 그려봅시다.
df = pd.read_csv('C:/Users/Kwon JaeWoo/Desktop/codeit_데이터사이언스 입문/3_5starbucks_drinks.csv', index_col = 0)
df
# Out:
#                                                                 Beverage  \
# Beverage_category
# Coffee                                                     Brewed Coffee
# Coffee                                                     Brewed Coffee
# Coffee                                                     Brewed Coffee
# Coffee                                                     Brewed Coffee
# Classic Espresso Drinks                                      Caffè Latte
# ...                                                                  ...
# Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df['Calories'].describe()
# Out:
# count    219.000000
# mean     201.584475
# std      102.353614
# min        3.000000
# 25%      125.000000
# 50%      190.000000
# 75%      270.000000
# max      510.000000
# Name: Calories, dtype: float64

# %%
df.plot(kind = 'box', y = 'Calories')
# Out:
# <AxesSubplot:>
